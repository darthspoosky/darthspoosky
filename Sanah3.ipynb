# %% [markdown]
# <a href="https://colab.research.google.com/github/darthspoosky/darthspoosky/blob/master/Sanah3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import io

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9a111eff-70cc-4804-8b49-16aceb09fc0c" name="files[]" multiple disabled />
#      <output id="result-9a111eff-70cc-4804-8b49-16aceb09fc0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ADE-NEG.txt to ADE-NEG.txt

# %%
file_name = "ADE-NEG.txt"
uploaded[file_name].decode("utf-8")
uploaded[file_name].decode("utf-8").split("\r\n")
# Out:
# '6460590 NEG Clioquinol intoxication occurring in the treatment of acrodermatitis enteropathica with reference to SMON outside of Japan.\r\n8600337 NEG "Retinoic acid syndrome" was prevented with short-time treatment of high dose (4 x 1.5 g/m2) cytarabine.\r\n8402502 NEG BACKGROUND: External beam radiation therapy often is avoided in the treatment of rhabdomyosarcoma (RMS) in young children because of the long-term sequelae.\r\n8700794 NEG Although the enuresis ceased, she developed throbbing headaches, nausea, vomiting, paresthesia, lethargy, fatigue, and altered mental status over the next 7 days.\r\n17662448 NEG A 42-year-old woman had uneventful bilateral laser-assisted subepithelial keratectomy (LASEK) to correct myopia.\r\n6970258 NEG A 16-year-old girl with erosive, polyarticular JRA showed no detectable change in her articular disease following nine exchanges.\r\n16426169 NEG Resection and use of a cyclooxygenase-2 inhibitor for treatment of pancreatic adenocarcinoma in a coc
# ...

# %%
def file (f):
  f_new = uploaded[file_name].decode("utf-8").split("\r\n")
  return(f_new)

# %%
file("ADE-NEG.txt")
# Out:
# ['6460590 NEG Clioquinol intoxication occurring in the treatment of acrodermatitis enteropathica with reference to SMON outside of Japan.',
#  '8600337 NEG "Retinoic acid syndrome" was prevented with short-time treatment of high dose (4 x 1.5 g/m2) cytarabine.',
#  '8402502 NEG BACKGROUND: External beam radiation therapy often is avoided in the treatment of rhabdomyosarcoma (RMS) in young children because of the long-term sequelae.',
#  '8700794 NEG Although the enuresis ceased, she developed throbbing headaches, nausea, vomiting, paresthesia, lethargy, fatigue, and altered mental status over the next 7 days.',
#  '17662448 NEG A 42-year-old woman had uneventful bilateral laser-assisted subepithelial keratectomy (LASEK) to correct myopia.',
#  '6970258 NEG A 16-year-old girl with erosive, polyarticular JRA showed no detectable change in her articular disease following nine exchanges.',
# ...
